# %% [markdown]
# ### NAME : CHINMAY HOLKAR
# ### EMAIL : chinmayholkar1998@gmail.com

# %%
# Question No 1
lst = list(input("Please enter the numbers for a list"))
sub_lst = list(input("Please enter the sublist in a order"))
a = len(sub_lst)
l = len(lst)
index_list = []
b = 0
for i in range (0,a):
    for j in range (b,l):
        if lst[j]==sub_lst[i]:
            index_list.append(j)
            b = j + 1
            break   
if len(index_list) == a:
    print("ITS A MATCH")
else:
    print("ITS GONE")
# Out:
# Please enter the numbers for a list1115557894
# Please enter the sublist in a order1594
# ITS A MATCH

# %% [markdown]
# ### REVIEWER I HAVE CORRECTED QUESTION 1 OF THE ASSIGNMENT AND ALSO SUBMITTING QUESTION 2 LATE (DATE : 9 MAY 2020 TIME : 11:26 PM) AS I HAD COLLEGE ASSIGNMENTS AS WELL , PLEASE CONSIDER MY REQUEST.  PLEASE CONSIDER ME

# %%
# Q2 TIC - TAC - TOE GAME


# Sir here I have used a tic tac toe board containing zeros as a basic board.
def printboard():
    print(lst[6],"|",lst[7],"|",lst[8],"\n","--------\n")
    print(lst[3],"|",lst[4],"|",lst[5],"\n","--------\n")
    print(lst[0],"|",lst[1],"|",lst[2],"\n","--------\n")

def INPUT():
    for i in range (1,3):
            a = str(input("Please enter 'X' or 'O' for player : %d " % i))
            marker.append(a)

def placement(index,position):
    lst[position] = marker[index]

def result(lst):
    for i in range(0,2):
        row_1 = 0
        row_2 = 0
        row_3 = 0
        col_1 = 0
        col_2 = 0
        col_3 = 0
        diag_1 = 0
        diag_2 = 0
        for j in range(0,3):
            if marker[i] == lst[j]:
                row_1 = row_1 + 1
        
        for j in range(3,6):
            if marker[i] == lst[j]:
                row_2 = row_2 + 1
        
        for j in range(6,9):
            if marker[i] == lst[j]:
                row_3 = row_3 + 1
        
        j = 0
        while j < 7:
            if marker[i] == lst[j]:
                col_1 = col_1 + 1
            j = j + 3
        
        j = 1
        while j < 8:
            if marker[i] == lst[j]:
                col_2 = col_2 + 1
            j = j + 3           
        
        j = 2
        while j < 9:
            if marker[i] == lst[j]:
                col_3 = col_3 + 1
            j = j + 3
        
        j = 0
        while j < 9:
            if marker[i] == lst[j]:
                diag_1 = diag_1 + 1
            j = j + 4
            
        j = 2
        while j < 7:
            if marker[i] == lst[j]:
                diag_2 = diag_2 + 1
            j = j + 2
        
        if row_1 == 3 or col_1 == 3 or diag_1 == 3 or row_2 == 3 or col_2 == 3 or diag_2 == 3 or row_3 == 3 or col_3 == 3:
            d = int(i) + 1
            print("The player ", str(d) ," is the winner")
            return 5
            break
        elif i == 0:
                 continue
        
def random_select():
    import random
    t = random.randint(1,2)
    print("The player", t ,"goes first")
    return t
    
def empty_check(position):
        if lst[position] == 0 :
                   return True

def full_or_not():
    u = 0
    for i in range(0,9):
        if lst[i] == 0:
             u = u + 1
    if u > 0:
        return False
    else:
        return True

def ask_position():
    position = int(input("Please enter your position from 1 to 9 :"))
    r = empty_check(position-1)
    if r == True:
        return position
    else:
        return False
    
def ask_play_again():
    g = input("Player do you want to play again :Y/N?")
    if g.upper() == 'Y':
        return True
while True:
    lst = [0,0,0,0,0,0,0,0,0]
    marker = []
    index = random_select()
    INPUT()
    while True:
        
        ASK = ask_position()
        if ASK == False :
            print("Change position")
            continue
        placement(index-1,ASK-1)
        printboard()
        return_value = result(lst)
        if  return_value == 5:
            break
        w = full_or_not()
        if w == True:
            print("The game is a tie")
            break
        else : 
            index = int(input("Please enter next player no 1 or 2 :"))
            continue
    h = ask_play_again()
    if h == True:
        continue
    else:
        print("The game is over.")
        break
# Out:
# The player 2 goes first
# Please enter 'X' or 'O' for player : 1 x
# Please enter 'X' or 'O' for player : 2 o
# Please enter your position from 1 to 9 :1
# 0 | 0 | 0
#  --------
#
# 0 | 0 | 0
#  --------
#
# o | 0 | 0
#  --------
#
# Please enter next player no 1 or 2 :1
# Please enter your position from 1 to 9 :2
# 0 | 0 | 0
#  --------
#
# 0 | 0 | 0
#  --------
#
# o | x | 0
#  --------
#
# Please enter next player no 1 or 2 :2
# Please enter your position from 1 to 9 :3
# 0 | 0 | 0
#  --------
#
# 0 | 0 | 0
#  --------
#
# o | x | o
#  --------
#
# Please enter next player no 1 or 2 :1
# Please enter your position from 1 to 9 :5
# 0 | 0 | 0
#  --------
#
# 0 | x | 0
#  --------
#
# o | x | o
#  --------
#
# Please enter next player no 1 or 2 :2
# Please enter your position from 1 to 9 :8
# 0 | o | 0
#  --------
#
# 0 | x | 0
#  --------
#
# o | x | o
#  --------
#
# Please enter next player no 1 or 2 :1
# Please enter your position from 1 to 9 :4
# 0 | o | 0
#  --------
#
# ...
